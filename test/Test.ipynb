# %% [markdown]
# ## Simple lattice nearest neighbor

# %%
using Percolation

# %%
site = simplenn(10,10,0.5)
# Out:
# Percolation.simplenn(10,10,0.5,[2 2 … 2 0; 0 1 … 1 1; … ; 1 0 … 0 0; 1 0 … 0 1])

# %%
percolation(site)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f59cdf31510>)
# (0,
# [2 2 … 2 0; 0 2 … 2 2; … ; 1 0 … 0 0; 1 0 … 0 1])

# %%
percolation(site, water=false)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f59cb5e2dd0>)
# (0,
# [2 2 … 2 0; 0 2 … 2 2; … ; 1 0 … 0 0; 1 0 … 0 1])

# %%
percolation(site, water=false, colorbar=false)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f59cb418f50>)
# (0,
# [2 2 … 2 0; 0 2 … 2 2; … ; 1 0 … 0 0; 1 0 … 0 1])

# %%
percolation(site, water=false, color="hot")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f59cb361ed0>)
# (0,
# [2 2 … 2 0; 0 2 … 2 2; … ; 1 0 … 0 0; 1 0 … 0 1])

# %%
percolation(site, water=false, fig=false)
# Out:
# (0,
# [2 2 … 2 0; 0 2 … 2 2; … ; 1 0 … 0 0; 1 0 … 0 1])

# %% [markdown]
# ## Simple lattice nearest and next nearest neighbor

# %%
site = simplennn(10,10,0.45)
# Out:
# Percolation.simplennn(10,10,0.45,[0 2 … 0 2; 0 1 … 0 1; … ; 0 0 … 0 1; 1 1 … 0 1])

# %%
percolation(site)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f59cb3b0050>)
# (1,
# [0 2 … 0 2; 0 2 … 0 2; … ; 0 0 … 0 2; 1 1 … 0 2])

# %%
percolation(site, water=false)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f59cb070ed0>)
# (1,
# [0 2 … 0 2; 0 2 … 0 2; … ; 0 0 … 0 2; 1 1 … 0 2])

# %%
percolation(site, water=false, colorbar=false)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f59caf4ef90>)
# (1,
# [0 2 … 0 2; 0 2 … 0 2; … ; 0 0 … 0 2; 1 1 … 0 2])

# %%
percolation(site, water=false, color="hot")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f59cb21ee10>)
# (1,
# [0 2 … 0 2; 0 2 … 0 2; … ; 0 0 … 0 2; 1 1 … 0 2])

# %%
percolation(site, water=false, fig=false)
# Out:
# (1,
# [0 2 … 0 2; 0 2 … 0 2; … ; 0 0 … 0 2; 1 1 … 0 2])

# %% [markdown]
# ## Simple lattice nn gif

# %%
site = simplenn(100,100,0.6)
percolationgif(site, colorbar=false, filename="animenn.gif")

# %%
site = simplennn(100,100,0.45)
percolationgif(site, colorbar=false, filename="animennn.gif")

# %% [markdown]
# ## Triangular lattice

# %%
site = trinn(100,100,0.5)
percolation(site)
# Out:
# LoadError: MethodError: no method matching *(::Percolation.trinn, ::Float64)
# Closest candidates are:
#   *(::Any, ::Any, !Matched::Any, !Matched::Any...) at operators.jl:138
#   *{T<:Number}(!Matched::Bool, ::T<:Number) at bool.jl:60
#   *(!Matched::Float64, ::Float64) at float.jl:244
#   ...
# while loading In[5], in expression starting on line 2
#
#  in PercolationPlot(::Percolation.trinn, ::Int64, ::Bool, ::String, ::Bool) at /home/tsuji/.julia/v0.5/Percolation/src/general/PercolationPlot.jl:41
#  in #percolation#1(::Bool, ::Bool, ::String, ::Bool, ::Function, ::Percolation.trinn) at /home/tsuji/.julia/v0.5/Percolation/src/general/percolation.jl:15
#  in percolation(::Percolation.trinn) at /home/tsuji/.julia/v0.5/Percolation/src/general/percolation.jl:4
