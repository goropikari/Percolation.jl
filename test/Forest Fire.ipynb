# %%
using PyPlot

# %%
function Grid(a, b, c, d)
    hx = [a, b]
    hy = [[i, i] for i in c:d]
    for i in 1:length(collect(c:d))
        plot(hx, hy[i], "k")
    end

    vx = [[i, i] for i in a:b]
    vy = [c, d]
    for i in 1:length(collect(a:b))
        plot(vx[i], vy, "k")
    end
end
# Out:
# Grid (generic function with 1 method)

# %%
Grid(0, 10, -4, 5)
axis("equal")
axis([-1, 11, -5, 6])
#grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff831ac03d0>)
# 4-element Array{Int64,1}:
#  -1
#  11
#  -5
#   6
